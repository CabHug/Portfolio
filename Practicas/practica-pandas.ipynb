# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# !python --version
print('NumPy', np.__version__)
print('Pandas', pd.__version__)
print('Matplotlib', mpl.__version__)
# Out:
# Python 3.13.5
# NumPy 2.1.3
# Pandas 2.2.3
# Matplotlib 3.10.0

# %% [markdown]
# ### Series
#
# Es la unidad basica de datos de pandas, pude ser creada con una lista, tupla, diccionarios a rreglos de numpy

# %%
# Una serie se crea con la funcion (pd.Series)
ciudades = ['Bogotá', 'Cali', 'Medellín','Barranquilla']
serie_ciudades = pd.Series(ciudades)
serie_ciudades
# Out:
# 0          Bogotá
# 1            Cali
# 2        Medellín
# 3    Barranquilla
# dtype: object

# %%
# Validamos el timpo de dato de serie_inicial
type(serie_ciudades)
# Out:
# pandas.core.series.Series

# %%
# en una serie puedo definir tanto los indices como los valores
habitantes = (11344000,2228000,2569000,1206000)

#En este punto vamos a crear una serie con sus indices
serie_habitantes = pd.Series(
    data=habitantes,
    index= ciudades
)
serie_habitantes
# Out:
# Bogotá          11344000
# Cali             2228000
# Medellín         2569000
# Barranquilla     1206000
# dtype: int64

# %% [markdown]
# ### Dataframe
# Un data frame en la estructura de datos mas amplia y conocida de pandas, esta representa una tabla en donde cada columna representa una variable del estudio y cada fila o registro una medicion
# El dataframe se compone de series y posee caracteristicas similares a la de una serie

# %%
datos = {
    'nombre_ciudad': ['Bogotá', 'Cali', 'Medellín','Barranquilla'],
    'poblacion' : (11344000,2228000,2569000,1206000),
    'altura' : np.array([2640,1018,1495,18])
}

# En este ejemplo el objeto de estudio son las ciudades
# Y cada columna es una variable con la que podemos describir a cada ciudad
ciudades = pd.DataFrame(datos)
ciudades
# Out:
#   nombre_ciudad  poblacion  altura
# 0        Bogotá   11344000    2640
# 1          Cali    2228000    1018
# 2      Medellín    2569000    1495
# 3  Barranquilla    1206000      18

# %% [markdown]
# ### Ejemplo con dataframe housing

# %%
# Importamos la informacion de housing
housing = pd.read_csv("https://raw.githubusercontent.com/HarryVargas96/UdeCataluna/main/Housing.csv")

# %%
# Obtenemos informacion sobre el dataframe
housing.shape

'''
Encontramos que el dataframe esta compuesto por 13 variables o columnas
y cuenta con 545 registros o mediciones
'''
# Out:
# '\nEncontramos que el dataframe esta compuesto por 13 variables o columnas\ny cuenta con 545 registros o mediciones\n'

# %%
# Con esta propiedad (index) puedo consultar que indices componen el DF
housing.index
# Out:
# RangeIndex(start=0, stop=545, step=1)

# %%
# consulto los valores (values) esta propiedad me permite ver los valores
#del DF como un arreglo de dos dimenciones
housing.values
# Out:
# array([[13300000, 7420, 4, ..., 2, 'yes', 'furnished'],
#        [12250000, 8960, 4, ..., 3, 'no', 'furnished'],
#        [12250000, 9960, 3, ..., 2, 'yes', 'semi-furnished'],
#        ...,
#        [1750000, 3620, 2, ..., 0, 'no', 'unfurnished'],
#        [1750000, 2910, 3, ..., 0, 'no', 'furnished'],
#        [1750000, 3850, 3, ..., 0, 'no', 'unfurnished']], dtype=object)

# %%
# Damos un vistaso a como se estructuran los datos con head
housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# Con tail puedo consultar las ultimas 5 filas del Df por defecto
housing.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
# El metodo .info() me muestra informacion detallada de las columnas que componen al DF
# me muestra un resumen de si contiene o no valores nulos
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
# El metodo .describe() me ayuda a tener un resumen estadistico descriptivo
# del DF solo para valores cuantitativo es decir numeros
housing.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
# Si en housing quiero incluir los valores cualitativos o variables puedo
# agegar el paraemtro object, de esa forma podemos ver todas las variables categoricas
# o al incluir 'all' vemos todas las variables
housing.describe(include='all')
# Out:
#                price          area    bedrooms   bathrooms     stories  \
# count   5.450000e+02    545.000000  545.000000  545.000000  545.000000
# unique           NaN           NaN         NaN         NaN         NaN
# top              NaN           NaN         NaN         NaN         NaN
# freq             NaN           NaN         NaN         NaN         NaN
# mean    4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std     1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min     1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%     3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%     4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%     5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max     1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#        mainroad guestroom basement hotwaterheating airconditioning  \
# ...

# %%
housing.describe(include=object)
# Out:
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishingstatus
# count               545
# unique                3
# top      semi-furnished
# freq                227

# %%
# puedo elegir solo una columna, para ahcer mas granular el estudio

precio = housing[['price']]
precio.head()
# Out:
#       price
# 0  13300000
# 1  12250000
# 2  12250000
# 3  12215000
# 4  11410000

# %%
# Existe un metodo que me permite tomar solo los datos de un tipo especifico
# .select_dtypes
# con esta funcion puedo tener todo el conjunto de datos de un tio de dato especifico listos para analizar


#housing.select_dtypes('number')
housing.select_dtypes('object')
# Out:
#     mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# 0        yes        no       no              no             yes      yes
# 1        yes        no       no              no             yes       no
# 2        yes        no      yes              no              no      yes
# 3        yes        no      yes              no             yes      yes
# 4        yes       yes      yes              no             yes       no
# ..       ...       ...      ...             ...             ...      ...
# 540      yes        no      yes              no              no       no
# 541       no        no       no              no              no       no
# 542      yes        no       no              no              no       no
# 543       no        no       no              no              no       no
# 544      yes        no       no              no              no       no
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# 2     semi-furnished
# ...

# %%
housing.select_dtypes('number').mean()
# Out:
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %%
housing['price'].mean()
# Out:
# np.float64(4766729.247706422)

# %%
housing['price'].max()
# Out:
# 13300000

# %%
housing['price'].min()
# Out:
# 1750000

# %% [markdown]
# #### Analisis de variables categoricas o cualitativas

# %%
# el metodo .unique() me muestra las valores unicos que conforman las mediciones de la variables
housing['furnishingstatus'].unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
# Con el metodo nunique() me permite regresar el numero de elementos unicos en la lista
housing['furnishingstatus'].nunique()
# Out:
# 3

# %%
# el metodo value_counts() me permite tener un conteo de cada una de los valores en la variable
housing['furnishingstatus'].value_counts()
# Out:
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64

# %%
# De esta forma puedo calcular el porcentaje de cada medida
numero_filas = housing.shape[0]

np.round(housing['furnishingstatus'].value_counts() / numero_filas*100 , 2)
# Out:
# furnishingstatus
# semi-furnished    41.65
# unfurnished       32.66
# furnished         25.69
# Name: count, dtype: float64

# %%
# importante en el metodo value_counts(normalize=True)
# esto me muestra los porcentajes o proporciones en los que se encuentra
# cada variable

housing['furnishingstatus'].value_counts(normalize=True)
# Out:
# furnishingstatus
# semi-furnished    0.416514
# unfurnished       0.326606
# furnished         0.256881
# Name: proportion, dtype: float64

# %% [markdown]
# #### Agrupacion de datos
#
# eL METODO .GROUPBY() de pandas me permite agrupar los datos respecto de una o varias variable spara despues poder hacer o plicar fucnines para encontrar valores importantes

# %%
# Este ejemplo me muestra como se agrupan los datos en funcion de los cuertos luego puedo consultar el precio y la media 
housing.groupby('bedrooms')['price'].mean() / 1000000
# Out:
# bedrooms
# 1    2.712500
# 2    3.632022
# 3    4.954598
# 4    5.729758
# 5    5.819800
# 6    4.791500
# Name: price, dtype: float64

# %%
# Puedo aplicar diferentes operaciones sobre una misma variable usando groupby() y agg()
housing.groupby('bedrooms').agg(
    {
        'price': 'mean',
        'area': 'mean'
    }
)
# Out:
#                  price         area
# bedrooms
# 1         2.712500e+06  3710.000000
# 2         3.632022e+06  4636.235294
# 3         4.954598e+06  5226.620000
# 4         5.729758e+06  5582.063158
# 5         5.819800e+06  6291.500000
# 6         4.791500e+06  3950.000000

# %%
# Puedo crear reportes mas detallados
housing.groupby('bedrooms').agg(
    {
        'price': ['min', 'max'],
        'area': ['min', 'max']
    }
)
# Out:
#             price            area
#               min       max   min    max
# bedrooms
# 1         2275000   3150000  3450   3970
# 2         1750000   7070000  1836  13200
# 3         1750000  12250000  1650  15600
# 4         2100000  13300000  2145  12090
# 5         1960000  10150000  1905  16200
# 6         3500000   6083000  3600   4300

# %% [markdown]
# ### Ejemplo de graficacion
#
# En este ejemplo se muestra la metrica ESTIMADOR, que apartir de una metrica de tendecia central me
# muestra una confiabilidad o un estimado de la variacion en un conjunto de datos

# %%
sns.barplot(
    data=housing,
    x='bedrooms',
    y='price',
    estimator='mean'
)

# En este caso el barplot muestra el promedio de las medidas para cada categorica indicada, osea el precio promedio de la cantidad de precios por categoria
# La lines sobre la barra indica la variabilidad de los valores siendo las mas grandes mas variables
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>
